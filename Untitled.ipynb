# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.stats as stats
#from fancyimpute import KNN
import warnings
warnings.filterwarnings('ignore')
#from geopy.distance import geodesic
#from geopy.distance import great_circle
from scipy.stats import chi2_contingency
import statsmodels.api as sm
from statsmodels.formula.api import ols
from patsy import dmatrices
from statsmodels.stats.outliers_influence import variance_inflation_factor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn import metrics
from sklearn.linear_model import LinearRegression,Ridge,Lasso
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RandomizedSearchCV
from sklearn.model_selection import cross_val_score
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
#import xgboost as xgb
#from xgboost import XGBRegressor
from sklearn.externals import joblib
# Pandas display options
pd.set_option('display.float_format', lambda x: '%.3f' % x)

# Set random seed 
RSEED = 100

# Visualizations
import matplotlib.pyplot as plt
# %matplotlib inline

plt.style.use('fivethirtyeight')
plt.rcParams['font.size'] = 18

import seaborn as sns
palette = sns.color_palette('Paired', 10)

# %%
os.chdir("D:\\EdWisor\\Project - Cab Rental")

# %%
test = pd.read_csv("test.csv")
train = pd.read_csv("train_cab.csv")

# %%
train.head(5)
# Out:
#   fare_amount          pickup_datetime  pickup_longitude  pickup_latitude  \
# 0         4.5  2009-06-15 17:26:21 UTC           -73.844           40.721
# 1        16.9  2010-01-05 16:52:16 UTC           -74.016           40.711
# 2         5.7  2011-08-18 00:35:00 UTC           -73.983           40.761
# 3         7.7  2012-04-21 04:30:42 UTC           -73.987           40.733
# 4         5.3  2010-03-09 07:51:00 UTC           -73.968           40.768
#
#    dropoff_longitude  dropoff_latitude  passenger_count
# 0            -73.842            40.712            1.000
# 1            -73.979            40.782            1.000
# 2            -73.991            40.751            2.000
# 3            -73.992            40.758            1.000
# 4            -73.957            40.784            1.000

# %%
test.head(5)
# Out:
#            pickup_datetime  pickup_longitude  pickup_latitude  \
# 0  2015-01-27 13:08:24 UTC           -73.973           40.764
# 1  2015-01-27 13:08:24 UTC           -73.987           40.719
# 2  2011-10-08 11:53:44 UTC           -73.983           40.751
# 3  2012-12-01 21:12:12 UTC           -73.981           40.768
# 4  2012-12-01 21:12:12 UTC           -73.966           40.790
#
#    dropoff_longitude  dropoff_latitude  passenger_count
# 0            -73.981            40.744                1
# 1            -73.999            40.739                1
# 2            -73.980            40.746                1
# 3            -73.990            40.752                1
# 4            -73.989            40.744                1

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16067 entries, 0 to 16066
# Data columns (total 7 columns):
# fare_amount          16043 non-null object
# pickup_datetime      16067 non-null object
# pickup_longitude     16067 non-null float64
# pickup_latitude      16067 non-null float64
# dropoff_longitude    16067 non-null float64
# dropoff_latitude     16067 non-null float64
# passenger_count      16012 non-null float64
# dtypes: float64(5), object(2)
# memory usage: 878.7+ KB

# %%
train.describe()
# Out:
#        pickup_longitude  pickup_latitude  dropoff_longitude  dropoff_latitude  \
# count         16067.000        16067.000          16067.000         16067.000
# mean            -72.463           39.915            -72.462            39.898
# std              10.578            6.827             10.575             6.187
# min             -74.438          -74.007            -74.429           -74.006
# 25%             -73.992           40.735            -73.991            40.735
# 50%             -73.982           40.753            -73.980            40.754
# 75%             -73.967           40.767            -73.964            40.768
# max              40.766          401.083             40.802            41.366
#
#        passenger_count
# count        16012.000
# mean             2.625
# std             60.844
# min              0.000
# 25%              1.000
# 50%              1.000
# 75%              2.000
# max           5345.000

# %%
# Remove na
train = train.dropna()

# %% [markdown]
# ## EDA

# %%
train = train[train['fare_amount'].str.contains("-")==False]
train.fare_amount = train.fare_amount.astype(float)
train.passenger_count = train.passenger_count.astype(float)
train = train.drop(train[train["fare_amount"]<1].index, axis = 0)

# %%
plt.figure(figsize = (10, 6))
sns.distplot(train.fare_amount)
plt.title('Distribution of Fare')
plt.figure(figsize=(8,5))
sns.kdeplot(np.log(train['fare_amount'].values)).set_title("Distribution of fare amount (log scale)")
# Out:
# Text(0.5,1,'Distribution of fare amount (log scale)')

# %%
train.describe()
# Out:
#        fare_amount  pickup_longitude  pickup_latitude  dropoff_longitude  \
# count    15982.000         15982.000        15982.000          15982.000
# mean        15.035           -72.464           39.915            -72.464
# std        431.268            10.575            6.830             10.572
# min          1.140           -74.438          -74.007            -74.429
# 25%          6.000           -73.992           40.735            -73.991
# 50%          8.500           -73.982           40.753            -73.980
# 75%         12.500           -73.967           40.767            -73.964
# max      54343.000            40.766          401.083             40.802
#
#        dropoff_latitude  passenger_count
# count         15982.000        15982.000
# mean             39.898            2.623
# std               6.187           60.900
# min             -74.006            0.000
# 25%              40.735            1.000
# 50%              40.754            1.000
# 75%              40.768            2.000
# max              41.366         5345.000

# %%
print(f"There are {len(train[train['passenger_count'] < 5])} passengers below the limit of 7")
print(f"There are {len(train[train['passenger_count'] > 7])} passengers above the limit of 7 which are {train.passenger_count[train.passenger_count > 7]}")
print(f"There are {len(train[train['passenger_count'] == 0])} values in passenger count having value = 0")
# Out:
# There are 14618 passengers below the limit of 7
# There are 19 passengers above the limit of 7 which are 233     236.000
# 263     456.000
# 293    5334.000
# 356     535.000
# 386     354.000
# 971     554.000
# 1007     53.000
# 1043     35.000
# 1107    345.000
# 1146   5345.000
# 1200    536.000
# 1242     43.000
# 8406     53.000
# 8445     58.000
# 8506    537.000
# 8571     87.000
# 8631     43.000
# 8715    531.200
# 8985    557.000
# Name: passenger_count, dtype: float64
# There are 57 values in passenger count having value = 0

# %%
train.groupby('passenger_count').size()
# Out:
# passenger_count
# 0.000          57
# 0.120           1
# 1.000       11238
# 1.300           1
# 2.000        2319
# 3.000         675
# 4.000         327
# 5.000        1044
# 6.000         301
# 35.000          1
# 43.000          2
# 53.000          2
# 58.000          1
# 87.000          1
# 236.000         1
# 345.000         1
# 354.000         1
# 456.000         1
# 531.200         1
# 535.000         1
# 536.000         1
# 537.000         1
# 554.000         1
# 557.000         1
# 5334.000        1
# 5345.000        1
# dtype: int64

# %%
train = train.drop(train[train.passenger_count < 1].index,axis = 0)

# %%
train = train.loc[~train.passenger_count.isin([0.120,1.300])]

# %%
train = train.drop(train[train.passenger_count > 7].index,axis = 0)

# %%
train = train.drop(train[train.fare_amount<6].index,axis = 0)

# %%
train = train[train.pickup_longitude.between(-180,180)]
train = train[train.pickup_latitude.between(-90,90)]
train = train[train.dropoff_longitude.between(-180,180)]
train = train[train.dropoff_latitude.between(-90,90)]

# %%
train.describe()
# Out:
#        fare_amount  pickup_longitude  pickup_latitude  dropoff_longitude  \
# count    12142.000         12142.000        12142.000          12142.000
# mean        18.274           -72.506           39.912            -72.512
# std        494.746            10.445            6.193             10.420
# min          6.000           -74.438          -74.007            -74.429
# 25%          7.700           -73.993           40.734            -73.991
# 50%         10.000           -73.982           40.752            -73.980
# 75%         14.500           -73.967           40.767            -73.962
# max      54343.000            40.766           41.366             40.802
#
#        dropoff_latitude  passenger_count
# count         12142.000        12142.000
# mean             39.926            1.655
# std               6.150            1.269
# min             -74.006            1.000
# 25%              40.733            1.000
# 50%              40.753            1.000
# 75%              40.768            2.000
# max              41.366            6.000

# %%
cat_var=['passenger_count']
num_var=['fare_amount','pickup_longitude','pickup_latitude','dropoff_longitude','dropoff_latitude']

# %%
# setting up the sns for plots
sns.set(style='darkgrid',palette='Set1')

# %%
plt.figure(figsize=(20,20))
plt.subplot(321)
_ = sns.distplot(train['fare_amount'],bins=50)
plt.subplot(322)
_ = sns.distplot(train['pickup_longitude'],bins=50)
plt.subplot(323)
_ = sns.distplot(train['pickup_latitude'],bins=50)
plt.subplot(324)
_ = sns.distplot(train['dropoff_longitude'],bins=50)
plt.subplot(325)
_ = sns.distplot(train['dropoff_latitude'],bins=50)
# plt.savefig('hist.png')
plt.show()

# %%
train["pickup_datetime"] = pd.to_datetime(train["pickup_datetime"],  errors='coerce')

# %%
plt.figure(figsize=(20,20))
plt.subplot(321)
_ = sns.violinplot(y='fare_amount',data=train)
plt.subplot(322)
_ = sns.violinplot(y='pickup_longitude',data=train)
plt.subplot(323)
_ = sns.violinplot(y='pickup_latitude',data=train)
plt.subplot(324)
_ = sns.violinplot(y='dropoff_longitude',data=train)
plt.subplot(325)
_ = sns.violinplot(y='dropoff_latitude',data=train)
plt.savefig('violin.png')
plt.show()

# %%
_ =sns.pairplot(data=train[num_var],kind='scatter',dropna=True)
_.fig.suptitle('Pairwise plot of all numerical variables')
# plt.savefig('Pairwise.png')
plt.show()

# %%
fig, axes = plt.subplots(1, 2, figsize = (15, 5), sharex=True, sharey=True)
axes = axes.flatten()

# Plot Longitude (x) and Latitude (y)
sns.regplot('pickup_longitude', 'dropoff_longitude', fit_reg = False,data = train, ax = axes[0]);
sns.regplot('pickup_latitude', 'dropoff_latitude', fit_reg = False,data = train, ax = axes[1]);
axes[0].set_title('Pickup Locations')
axes[1].set_title('Dropoff Locations')
# Out:
# Text(0.5,1,'Dropoff Locations')

# %% [markdown]
# ## Removing values which are not within desired range(outlier) depending upon basic understanding of dataset.
# #### 1.Fare amount has a negative value, which doesn't make sense. A price amount cannot be -ve and also cannot be 0. So we will remove these fields.

# %%
sum(train['fare_amount']<1)
# Out:
# 0

# %%
sum((train["passenger_count"].astype(float))<1)
sum((test["passenger_count"].astype(int))<1)
# Out:
# 0

# %%
test["passenger_count"].unique()
# Out:
# array([1, 2, 3, 4, 5, 6], dtype=int64)

# %%
train["passenger_count"].unique()
# Out:
# array(['1.0', '2.0', '3.0', 'nan', '6.0', '5.0', '4.0', '236.0', '456.0',
#        '5334.0', '0.0', '535.0', '354.0', '554.0', '53.0', '35.0',
#        '345.0', '5345.0', '536.0', '43.0', '58.0', '537.0', '87.0',
#        '531.2', '1.3', '0.12', '557.0'], dtype=object)
